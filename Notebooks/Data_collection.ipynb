# %%
import sys

print(sys.executable)
# Out:
# c:\Projects\UIDAI_Hackathon_project\venv\Scripts\python.exe

# %%
from ingestion.api_ingestion import fetch_and_store_state_data
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ingestion.api_ingestion import fetch_and_store_state_data
#
# File C:\Projects\UIDAI_Hackathon_project\src\ingestion\api_ingestion.py:6
#       3 import requests
#       4 import pandas as pd
# ----> 6 from config.api_config import (
#       7     BASE_URL,
#       8     API_KEY,
#       9     AADHAAR_ENROLMENT_RESOURCE_ID,
#      10     AADHAAR_DEMOGRAPHIC_RESOURCE_ID,
#      11     AADHAAR_BIOMETRIC_RESOURCE_ID,
#      12     DEFAULT_API_PARAMS
#      13 )
#      15 from storage.csv_store import save_dataframe_to_csv
#      16 from utils.state_mapper import normalize_state_name
#
# File C:\Projects\UIDAI_Hackathon_project\src\config\api_config.py:23
#      20     raise EnvironmentError("API_KEY (enrolment) not found in environment variables")
#      22 if API_KEY_DEMOGRAPHIC is None:
# ...

# %%
df_karnataka = fetch_and_store_state_data("Karnataka")
df_karnataka.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_karnataka = fetch_and_store_state_data("Karnataka")
#       2 df_karnataka.head()
#
# NameError: name 'fetch_and_store_state_data' is not defined

# %%
df_karnataka.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_karnataka.shape()
#
# NameError: name 'df_karnataka' is not defined

# %%
import os

print("API_KEY:", os.getenv("API_KEY"))
print("API_KEY_DEMOGRAPHIC:", os.getenv("API_KEY_DEMOGRAPHIC"))
print("API_KEY_BIOMETRIC:", os.getenv("API_KEY_BIOMETRIC"))
# Out:
# API_KEY: 579b464db66ec23bdd00000149bb208ba8bb48e77161d28db6f15f1d
# API_KEY_DEMOGRAPHIC: None
# API_KEY_BIOMETRIC: None

# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parents[1]
sys.path.append(str(ROOT))

# %%
from src.ingestion.api_ingestion import fetch_and_store_state_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.ingestion.api_ingestion import fetch_and_store_state_data
#
# File c:\Users\kanis\OneDrive\Desktop\UIDAI_Hackathon_project\src\ingestion\api_ingestion.py:10
#       2 import pandas as pd
#       4 from src.config.api_config import (
#       5     BASE_URL,
#       6     API_KEY,
#       7     AADHAAR_ENROLMENT_RESOURCE_ID,
#       8     DEFAULT_API_PARAMS
#       9 )
# ---> 10 from src.storage.csv_store import save_dataframe_to_csv
#      11 from src.utils.state_mapper import normalize_state_name
#      14 def fetch_and_store_state_data(state_name: str) -> pd.DataFrame:
#
# ImportError: cannot import name 'save_dataframe_to_csv' from 'src.storage.csv_store' (c:\Users\kanis\OneDrive\Desktop\UIDAI_Hackathon_project\src\storage\csv_store.py)

# %%
df_karnataka = fetch_and_store_state_data("Karnataka")
df_karnataka.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_karnataka = fetch_and_store_state_data("Karnataka")
#       2 df_karnataka.head()
#
# NameError: name 'fetch_and_store_state_data' is not defined

# %%
import os
os.getcwd()
# Out:
# 'c:\\Projects\\UIDAI_Hackathon_project\\Notebooks'

# %%
import sys
sys.path[0]
# Out:
# 'C:\\Users\\kanis\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip'
